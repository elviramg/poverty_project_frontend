# %%
import json
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv('data/Labor_Poverty.csv')

# Filter the dataset based on the selected date
selected_data = df[df['Unnamed: 0'] == '07-2006'].transpose().reset_index()
selected_data.columns = ['State', 'Poverty Rate']
selected_data = selected_data.iloc[1:]  # Exclude the date row
selected_data.set_index("State", inplace=True)

# %%
# Load GeoJSON file
with open("data/mexicoHigh.json") as response:
    geo = json.load(response)

# %%
geo
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-100.8323, 24.5549],
#       [-100.854, 24.5395],
#       [-100.8864, 24.5235],
#       [-100.9009, 24.4583],
#       [-100.9482, 24.4216],
#       [-100.9758, 24.3588],
#       [-101.0149, 24.3404],
#       [-101.0781, 24.3429],
#       [-101.1047, 24.324],
#       [-101.1134, 24.2694],
#       [-101.1404, 24.2356],
#       [-101.1502, 24.2042],
#       [-101.2042, 24.1718],
#       [-101.2791, 24.1545],
#       [-101.3047, 24.1318],
#       [-101.3221, 24.0999],
#       [-101.3207, 24.0371],
#       [-101.3381, 24.0052],
#       [-101.2975, 23.9617],
#       [-101.3125, 23.9206],
#       [-101.3337, 23.8849],
#       [-101.3448, 23.853],
#       [-101.3888, 23.7965],
#       [-101.4443, 23.7791],
#       [-101.5613, 23.7476],
#       [-101.5782, 23.738],
#       [-101.626, 23.6844],
#       [-101.6801, 23.595],
#       [-101.7168, 23.5487],
# ...

# %%
# Convert GeoJSON to GeoDataFrame
gdf = gpd.GeoDataFrame.from_features((geo))

# Merge GeoDataFrame with selected data
merged = gdf.join(selected_data.astype(float))

# Plotting
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
merged.plot(column='geometry', cmap='YlOrRd', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)
plt.title(f'Poverty Rate by State in Mexico for 07-2006')

# Display on Streamlit
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/IPython/core/formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/IPython/core/pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# ...
